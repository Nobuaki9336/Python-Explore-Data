# %% [markdown]
# #### First Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Web coding\Practice_1.csv", encoding='unicode_escape')

df
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0           I182070945           619                          Larceny
# 1           I182070943          1402                        Vandalism
# 2           I182070941          3410                            Towed
# 3           I182070940          3114             Investigate Property
# 4           I182070938          3114             Investigate Property
# ...                ...           ...                              ...
# 139995      I172028918          3006               Medical Assistance
# 139996      I172028917          1874                   Drug Violation
# 139997      I172028916          2204                 Liquor Violation
# 139998      I172028915          3830  Motor Vehicle Accident Response
# 139999      I172028913          3115               Investigate Person
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   object
#  1   Car Model                1007 non-null   object
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          997 non-null    object
#  4   Horsepower               1007 non-null   object
#  5   Torque (lb-ft)           1004 non-null   object
#  6   0-60 MPH Time (seconds)  1007 non-null   object
#  7   Price (in USD)           1007 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 63.1+ KB

# %%
df.describe()
# Out:
#               Year
# count  1007.000000
# mean   2021.201589
# std       2.019802
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2023.000000

# %%
df.shape
# Out:
# (1007, 8)

# %%
df2 = pd.set_option('display.max.rows',1010)
df2

# %%
df.head(100)
# Out:
#          Car Make                      Car Model  Year Engine Size (L)  \
# 0         Porsche                            911  2022               3
# 1     Lamborghini                        Huracan  2021             5.2
# 2         Ferrari                        488 GTB  2022             3.9
# 3            Audi                             R8  2022             5.2
# 4         McLaren                           720S  2021               4
# 5             BMW                             M8  2022             4.4
# 6   Mercedes-Benz                         AMG GT  2021               4
# 7       Chevrolet                       Corvette  2021             6.2
# 8            Ford           Mustang Shelby GT500  2022             5.2
# 9          Nissan                     GT-R Nismo  2021             3.8
# 10   Aston Martin                           DB11  2021             5.2
# 11        Bugatti                         Chiron  2021               8
# ...

# %%
df.tail(100)
# Out:
#            Car Make                  Car Model  Year Engine Size (L)  \
# 907     Lamborghini                  Aventador  2021             6.5
# 908           Lexus                     LC 500  2022               5
# 909           Lotus                   Evora GT  2021             3.5
# 910        Maserati                GranTurismo  2021             4.7
# 911         McLaren                         GT  2021               4
# 912   Mercedes-Benz                   AMG C 63  2021               4
# 913          Nissan                 370Z Nismo  2021             3.7
# 914         Porsche                   Panamera  2022             2.9
# 915          Subaru                    WRX STI  2021             2.5
# 916           Tesla                   Roadster  2022             NaN
# 917         Porsche                 718 Cayman  2022               2
# 918     Lamborghini                  Aventador  2021             6.5
# 919         Ferrari              SF90 Stradale  2022               4
# ...

# %%
df.loc[888]
# Out:
# Car Make                   Jaguar
# Car Model                  F-Type
# Year                         2021
# Engine Size (L)                 3
# Horsepower                    380
# Torque (lb-ft)                339
# 0-60 MPH Time (seconds)       4.9
# Price (in USD)             62,750
# Name: 888, dtype: object

# %% [markdown]
# #### Filtering and Ordering in Pandas

# %%
# Filter BMW Car 
df[df['Car Make'] == 'BMW']
# Out:
#     Car Make       Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 5        BMW              M8  2022             4.4        617            553
# 32       BMW              M4  2022               3        503            479
# 42       BMW              i8  2020  1.5 + Electric        369            420
# 49       BMW              M4  2022               3        503            479
# 61       BMW              M5  2022             4.4        600            553
# 64       BMW              M2  2022               3        405            406
# 76       BMW              M4  2022               3        473            406
# 107      BMW              M4  2022               3        503            479
# 120      BMW              M2  2022               3        405            406
# 128      BMW              M2  2022               3        405            406
# 142      BMW         Z4 M40i  2022               3        382            369
# ...

# %%
df['Price (in USD)'] = df['Price (in USD)'].str.replace(',', '')
df['Price (in USD)'] = pd.to_numeric(df['Price (in USD)'])

# %%
df[df['Price (in USD)'] > 2500000]
# Out:
#          Car Make                Car Model  Year Engine Size (L) Horsepower  \
# 11        Bugatti                   Chiron  2021               8       1500
# 14     Koenigsegg                    Jesko  2021               5       1280
# 24         Pagani                   Huayra  2021               6        720
# 85        Bugatti                   Chiron  2022               8       1500
# 88     Koenigsegg                    Jesko  2022               5       1600
# 95         Pagani                   Huayra  2022               6        764
# 113       Bugatti                   Chiron  2021               8       1500
# 158       Bugatti                   Chiron  2021               8       1500
# 161    Koenigsegg                    Jesko  2022               5       1600
# 166        Pagani                   Huayra  2020               6        720
# 174      W Motors         Lykan Hypersport  2015             3.7        780
# ...

# %%
# Remove ',' & '+' sign in the column and then change the dtype to numeric 
df['Horsepower'] = df['Horsepower'].str.replace(r'[+,]', '', regex=True)
df['Horsepower'] = pd.to_numeric(df['Horsepower'])

# %%
# Filer Car Horsepower over or equal 1000 and order it in dscending order
df[df['Horsepower'] >= 1000].sort_values(by='Horsepower',ascending=False)
# Out:
#          Car Make                Car Model  Year       Engine Size (L)  \
# 885         Tesla                 Roadster  2022                     0
# 389         Tesla                 Roadster  2022                   NaN
# 916         Tesla                 Roadster  2022                   NaN
# 877         Lotus                    Evija  2021              Electric
# 523         Lotus                    Evija  2022              Electric
# 987         Lotus                    Evija  2022              Electric
# 420         Lotus                    Evija  2022              Electric
# 1003        Lotus                    Evija  2021        Electric Motor
# 697         Lotus                    Evija  2022                   NaN
# 526         Rimac                    C_Two  2022              Electric
# 439         Rimac                    C_Two  2021              Electric
# 824         Rimac                   Nevera  2021              Electric
# ...

# %%
columns_to_keep = ['Car Make', 'Horsepower','Price (in USD)']

df2 = df[columns_to_keep]

df2

# %%
df2.groupby('Car Make').max()
# Out:
#                Horsepower  Price (in USD)
# Car Make
# Acura                 573          159495
# Alfa Romeo            505           83250
# Alpine                288           71500
# Ariel                 320           75000
# Aston Martin          715          330000
# Audi                  591          183300
# BMW                   617          148500
# Bentley               650          300000
# Bugatti              1578         5200000
# Chevrolet             650           85000
# Dodge                 797          126190
# Ferrari               986          625000
# Ford                  760          500000
# Jaguar                575          105900
# Kia                   368           52200
# Koenigsegg           1600         3000000
# Lamborghini           819         3600000
# Lexus                 471          102550
# Lotus                2000         2800000
# Maserati              621          210000
# Mazda                 181           26830
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df2.plot.area(figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# #### First Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Web coding\Cutted.csv", encoding='unicode_escape')

df
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0           I182070945           619                          Larceny
# 1           I182070943          1402                        Vandalism
# 2           I182070941          3410                            Towed
# 3           I182070940          3114             Investigate Property
# 4           I182070938          3114             Investigate Property
# ...                ...           ...                              ...
# 139995      I172028918          3006               Medical Assistance
# 139996      I172028917          1874                   Drug Violation
# 139997      I172028916          2204                 Liquor Violation
# 139998      I172028915          3830  Motor Vehicle Accident Response
# 139999      I172028913          3115               Investigate Person
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# ...

# %%
# Checking the shape of the data.
df.shape
# Out:
# (140000, 17)

# %%
# Quick check on how the dataset looks like
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
df.tail()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 139995      I172028918          3006               Medical Assistance
# 139996      I172028917          1874                   Drug Violation
# 139997      I172028916          2204                 Liquor Violation
# 139998      I172028915          3830  Motor Vehicle Accident Response
# 139999      I172028913          3115               Investigate Person
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 139995          SICK/INJURED/MEDICAL - PERSON      E18            555
# 139996                          DRUGS - OTHER       B3            427
# 139997                   LIQUOR LAW VIOLATION       A1
# 139998  M/V - LEAVING SCENE - PERSONAL INJURY       B2            279
# 139999                     INVESTIGATE PERSON       B2            329
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# ...

# %%
# Counting the duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Dropping the duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Check shape again
df.shape
# Out:
# (140000, 17)

# %% [markdown]
# ### Explore the dataset

# %%
pd.set_option('display.max_rows', None)
df.tail(100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      140000 non-null  object
#  1   OFFENSE_CODE         140000 non-null  int64
#  2   OFFENSE_CODE_GROUP   140000 non-null  object
#  3   OFFENSE_DESCRIPTION  140000 non-null  object
#  4   DISTRICT             138966 non-null  object
#  5   REPORTING_AREA       140000 non-null  object
#  6   SHOOTING             472 non-null     object
#  7   OCCURRED_ON_DATE     140000 non-null  object
#  8   YEAR                 140000 non-null  int64
#  9   MONTH                140000 non-null  int64
#  10  DAY_OF_WEEK          140000 non-null  object
#  11  HOUR                 140000 non-null  int64
#  12  UCR_PART             139953 non-null  object
#  13  STREET               137399 non-null  object
#  14  Lat                  130745 non-null  float64
# ...

# %%
# Changing the data type from object to datetime for the OCCURRED_ON_DATE column
df.OCCURRED_ON_DATE = pd.to_datetime(df.OCCURRED_ON_DATE)

# %%
# Check the Dtype again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      140000 non-null  object
#  1   OFFENSE_CODE         140000 non-null  int64
#  2   OFFENSE_CODE_GROUP   140000 non-null  object
#  3   OFFENSE_DESCRIPTION  140000 non-null  object
#  4   DISTRICT             138966 non-null  object
#  5   REPORTING_AREA       140000 non-null  object
#  6   SHOOTING             472 non-null     object
#  7   OCCURRED_ON_DATE     140000 non-null  datetime64[ns]
#  8   YEAR                 140000 non-null  int64
#  9   MONTH                140000 non-null  int64
#  10  DAY_OF_WEEK          140000 non-null  object
#  11  HOUR                 140000 non-null  int64
#  12  UCR_PART             139953 non-null  object
#  13  STREET               137399 non-null  object
# ...

# %%
# Extract datetime information frome the OCCURRED_ON_DATE column
df.OCCURRED_ON_DATE.dt.year

# %%
df.OCCURRED_ON_DATE.dt.month

# %%
df['WEEK_OF_YEAR'] = df['OCCURRED_ON_DATE'].dt.isocalendar().week
df['WEEK_OF_YEAR']

# %%
df.OCCURRED_ON_DATE.dt.hour

# %%
df.OCCURRED_ON_DATE.dt.minute

# %%
df.describe()
# Out:
#         OFFENSE_CODE               OCCURRED_ON_DATE           YEAR  \
# count  140000.000000                         140000  140000.000000
# mean     2355.736364  2017-12-18 13:42:17.159000064    2017.466329
# min       111.000000            2015-06-15 00:00:00    2015.000000
# 25%      1102.000000            2017-08-10 17:38:15    2017.000000
# 50%      3006.000000            2017-12-12 18:57:30    2017.000000
# 75%      3201.000000            2018-05-01 20:52:31    2018.000000
# max      3831.000000            2018-09-03 21:25:00    2018.000000
# std      1176.828201                            NaN       0.503967
#
#                MONTH           HOUR            Lat           Long  \
# count  140000.000000  140000.000000  130745.000000  130745.000000
# mean        6.488221      13.107207      42.183651     -70.858957
# min         1.000000       0.000000      -1.000000     -71.178674
# 25%         4.000000       9.000000      42.296934     -71.097437
# ...

# %%
# summary information on the non-numeric columns
df.describe(include=object)
# Out:
#        INCIDENT_NUMBER               OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# count           140000                           140000              140000
# unique          124258                               65                 186
# top         I172096394  Motor Vehicle Accident Response  INVESTIGATE PERSON
# freq                10                            16444                9135
#
#        DISTRICT REPORTING_AREA SHOOTING DAY_OF_WEEK    UCR_PART  \
# count    138966         140000      472      140000      139953
# unique       12            878        1           7           4
# top          B2                       Y      Friday  Part Three
# freq      21304           9995      472       21427       72512
#
#                STREET                  Location
# count          137399                    140000
# unique           3899                     14667
# top     WASHINGTON ST  (0.00000000, 0.00000000)
# freq             6311                      9255

# %%
# Show the missing values column
df.columns[np.sum(df.isnull()) > 0]
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Index(['DISTRICT', 'SHOOTING', 'UCR_PART', 'STREET', 'Lat', 'Long'], dtype='object')

# %%
# Checking for the number of missing values in each column
df[df.columns].isnull().sum()
# Out:
# INCIDENT_NUMBER             0
# OFFENSE_CODE                0
# OFFENSE_CODE_GROUP          0
# OFFENSE_DESCRIPTION         0
# DISTRICT                 1034
# REPORTING_AREA              0
# SHOOTING               139528
# OCCURRED_ON_DATE            0
# YEAR                        0
# MONTH                       0
# DAY_OF_WEEK                 0
# HOUR                        0
# UCR_PART                   47
# STREET                   2601
# Lat                      9255
# Long                     9255
# Location                    0
# WEEK_OF_YEAR                0
# dtype: int64

# %%
# Checking for columns with no missing values
df.columns[np.sum(df.isnull()) == 0]
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'YEAR',
#        'MONTH', 'DAY_OF_WEEK', 'HOUR', 'Location', 'WEEK_OF_YEAR'],
#       dtype='object')

# %% [markdown]
# ### Questions

# %%
# What are the most common crimes
df.OFFENSE_CODE_GROUP.value_counts()
# Out:
# OFFENSE_CODE_GROUP
# Motor Vehicle Accident Response     16444
# Medical Assistance                  11184
# Larceny                             11144
# Investigate Person                   9134
# Other                                7739
# Simple Assault                       7249
# Drug Violation                       6532
# Vandalism                            6312
# Verbal Disputes                      6206
# Investigate Property                 5468
# Towed                                5413
# Property Lost                        4616
# Larceny From Motor Vehicle           4414
# Aggravated Assault                   3449
# Warrant Arrests                      3320
# Fraud                                2665
# Violations                           2347
# Auto Theft                           2011
# Missing Person Located               1993
# Residential Burglary                 1977
# Harassment                           1950
# Property Found                       1856
# ...

# %%
offense_group_vals = df.OFFENSE_CODE_GROUP.value_counts()[:10]

display((offense_group_vals / df.shape[0])* 100)
# Out:
# OFFENSE_CODE_GROUP
# Motor Vehicle Accident Response    11.745714
# Medical Assistance                  7.988571
# Larceny                             7.960000
# Investigate Person                  6.524286
# Other                               5.527857
# Simple Assault                      5.177857
# Drug Violation                      4.665714
# Vandalism                           4.508571
# Verbal Disputes                     4.432857
# Investigate Property                3.905714
# Name: count, dtype: float64

# %%
# Creating a bar chart of the Top 10 offense groups  

plt.figure(figsize=(9, 5))

((offense_group_vals / df.shape[0])* 100).plot(kind='bar');
plt.title('Top 10 Offense Groups');

# %%
# What are the least common offense groups?
df.OFFENSE_CODE_GROUP.value_counts().sort_values(ascending=True)[:10]
# Out:
# OFFENSE_CODE_GROUP
# INVESTIGATE PERSON        1
# Manslaughter              2
# Biological Threat         2
# HUMAN TRAFFICKING         4
# Gambling                  6
# Explosives               12
# Phone Call Complaints    14
# Bomb Hoax                14
# Aircraft                 19
# HOME INVASION            42
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN 2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN 2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN 2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN 2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN 2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...
